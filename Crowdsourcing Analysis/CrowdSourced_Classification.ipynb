# %% [markdown]
# # In this notebook, we analyze crowdsourced data by answering the following 3 questions:
# - which model best **predicted** the crowdsourced label?
# - which model performed best when **blended** with the crowdsourced label?
# - which model had the highest performance when only taking the agreeing label between the model and the crowdsourced output, and computing accuracy on this **subsection**?

# %% [markdown]
# ## Load crowdsourced .csv file, remove rows with missing data, and remove rows with less than 2 votes

# %%
import pandas as pd
path_to_crowdsourced_data_csv_file = './CrowdSourced_Data.csv'
crowdsourcing = pd.read_csv(path_to_crowdsourced_data_csv_file)
print(len(crowdsourcing))
crowdsourcing.dropna(how='all').sample(2)
# Out:
# 7051
#      initialLabel  binaryInitialLabel  \
# 1813        FALSE                   0
# 3620        FALSE                   0
#
#                                                   title  \
# 1813   Brazilian President Jair Bolsonaro declared a...
# 3620   â€œA lootingâ€ in a supermarket due to the c...
#
#                                                     url  numTrueVotes  \
# 1813  https://www.poynter.org/?ifcn_misinformation=b...             2
# 3620  https://www.poynter.org/?ifcn_misinformation=a...             0
#
#       numFalseVotes  totalVotes  maxVotes  interraterPercentAgreement  \
# 1813              3           5         3                         0.6
# 3620              3           3         3                         1.0
#
#       agreementWithLabel  votersLabel  voterLabelWasAccurate  \
# 1813                 0.6            0                      1
# 3620                 1.0            0                      1
#
#       averageInterraterPercentAgreement  averageAgreementWithLabel  \
# 1813                                NaN                        NaN
# 3620                                NaN                        NaN
#
#       percentOfAgreeingDecisions
# 1813                         NaN
# 3620                         NaN

# %%
#remove rows from crowdsoucing with less than 2 totalVotes
crowdsourcing = crowdsourcing[crowdsourcing['totalVotes'] > 2]
len(crowdsourcing)
# Out:
# 6931

# %%
# Out:
#      initialLabel  binaryInitialLabel  \
# 0           FALSE                   0
# 1           FALSE                   0
# 2           FALSE                   0
# 3            TRUE                   1
# 4            TRUE                   1
# ...           ...                 ...
# 7046        FALSE                   0
# 7047         TRUE                   1
# 7048         TRUE                   1
# 7049         TRUE                   1
# 7050         TRUE                   1
#
#                                                   title  \
# 0          Video clip shows people keep leaving Phuket.
# 1      Using hot air from a hair dryer on sinuses ca...
# 2      This video shows a woman eating a bat soup in...
# 3     Premier League looking at 'clinical passports'...
# 4     What to expect as GOP hammers out its coronavi...
# ...                                                 ...
# 7046   Images of an alleged fire at New Yorkâ€™s Leb...
# 7047            Pfizer sales take a hit during pandemic
# 7048  COVID-19 vaccine's human trials show promise -...
# 7049  Coronavirus in Scotland: Economic recovery pla...
# 7050  U.S. testing czar: Everyone who 'needs' a covi...
#
#                                                     url  numTrueVotes  \
# 0     https://www.poynter.org/?ifcn_misinformation=s...             5
# 1     https://www.poynter.org/?ifcn_misinformation=u...             0
# 2     https://www.poynter.org/?ifcn_misinformation=t...             0
# 3         https://www.bbc.co.uk/sport/football/53605863             5
# 4     https://www.politico.com/newsletters/weekly-ed...             5
# ...                                                 ...           ...
# 7046  https://www.poynter.org/?ifcn_misinformation=i...             0
# 7047  https://apnews.com/66e1cede592436a42bdba32bfdf...             1
# 7048  https://www.reuters.com/video/watch/idP4Cb?now...             1
# 7049  https://www.bbc.co.uk/news/uk-scotland-scotlan...             0
# 7050  https://www.politico.com/news/2020/07/26/us-te...             1
#
#       numFalseVotes  totalVotes  maxVotes  interraterPercentAgreement  \
# 0                 1           6         5                    0.833333
# 1                 5           5         5                    1.000000
# 2                 5           5         5                    1.000000
# 3                 2           7         5                    0.714286
# 4                 1           6         5                    0.833333
# ...             ...         ...       ...                         ...
# 7046              1           1         1                    1.000000
# 7047              1           2         1                    0.500000
# 7048              0           1         1                    1.000000
# 7049              1           1         1                    1.000000
# 7050              0           1         1                    1.000000
#
#       agreementWithLabel  votersLabel  voterLabelWasAccurate  \
# 0               0.166667            1                      0
# 1               1.000000            0                      1
# 2               1.000000            0                      1
# 3               0.714286            1                      1
# 4               0.833333            1                      1
# ...                  ...          ...                    ...
# 7046            1.000000            0                      1
# 7047            0.500000            1                      1
# 7048            1.000000            1                      1
# 7049            0.000000            0                      0
# 7050            1.000000            1                      1
#
#       averageInterraterPercentAgreement  averageAgreementWithLabel  \
# 0                              0.833511                   0.675247
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
# 3                                   NaN                        NaN
# 4                                   NaN                        NaN
# ...                                 ...                        ...
# 7046                                NaN                        NaN
# 7047                                NaN                        NaN
# 7048                                NaN                        NaN
# 7049                                NaN                        NaN
# 7050                                NaN                        NaN
#
#       percentOfAgreeingDecisions
# 0                       0.731386
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 7046                         NaN
# 7047                         NaN
# 7048                         NaN
# 7049                         NaN
# 7050                         NaN
#
# [7051 rows x 15 columns]

# %%
crowdsourcing['softLabel']=crowdsourcing['numTrueVotes']/crowdsourcing['totalVotes']
df_crowdsourcing = pd.DataFrame({'title' : crowdsourcing['title'], 'label':crowdsourcing['binaryInitialLabel'], 'voterSoftLabel':crowdsourcing['softLabel'],'voterLabel': crowdsourcing['votersLabel']})
df_crowdsourcing=df_crowdsourcing.dropna()
df_crowdsourcing = df_crowdsourcing.reset_index(drop=True)
df_crowdsourcing.sample(2)
# Out:
#                                                   title  label  \
# 776   Despite pandemic, Merck increases 2Q net, prof...      1
# 3709   Infographic claiming that the coronavirus pan...      0
#
#       voterSoftLabel  voterLabel
# 776              1.0           1
# 3709             1.0           1

# %% [markdown]
# ## Question 1 which model best **predicted** the crowdsourced label?

# %%
import os
path_to_prediction_folder = '../Model_Predictions/'
prediction_csv_files = os.listdir(path_to_prediction_folder)
prediction_csv_files[2]
# Out:
# 'finetune_bert_CoAID_GossipCop_Prediction.csv'

# %%
attampt = prediction_csv_files[2]
attampt_file = pd.read_csv(path_to_prediction_folder+attampt)
attampt_file.sample(2)
# Out:
#       Unnamed: 0  softLabel  label  prediction  accuracy       f1  precision  \
# 4068        4068   0.000464      0           0  0.804823  0.72892   0.973684
# 2708        2708   0.000481      0           0  0.804823  0.72892   0.973684
#
#         recall
# 4068  0.582494
# 2708  0.582494

# %% [markdown]
# List all model prediction results

# %%
#drop string not end with .csv
prediction_csv_files = [x for x in prediction_csv_files if x.endswith('.csv')]
prediction_csv_files
# Out:
# ['bert-base_Prediction.csv',
#  'XLNet_on_Gossip_Prediction.csv',
#  'finetune_bert_CoAID_GossipCop_Prediction.csv',
#  'roberta-fake-news_CoAID_PolitiFact_Prediction.csv',
#  'finetune_bert_CoAID_Prediction.csv',
#  'XLNet_on_CoAID_FNN_Prediction.csv',
#  'Text_CNN_Politi_predict.csv',
#  'finetune_bert_PolitiFact_Prediction.csv',
#  'Fake-News-Bert-Detect_FNN_Prediction.csv',
#  'XLNet_on_CoAID_Gossip_Prediction.csv',
#  'roberta-fake-news_FNN_Prediction.csv',
#  'roberta-fake-news_PolitiFact_Prediction.csv',
#  'Text_CNN_Gossip_predict.csv',
#  'roberta-fake-news_CoAID_GossipCop_Prediction.csv',
#  'Fake-News-Bert-Detect_GossipCop_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&GossipCop_Prediction.csv',
#  'XLNet-base_Prediction.csv',
#  'Text_CNN_CoAID_Gossip_predict.csv',
#  'XLNet_on_CoAID_Politi_Prediction.csv',
#  'XLNet_on_CoAID_Prediction.csv',
#  'roberta-fake-news_GossipCop_Prediction.csv',
#  'finetune_bert_CoAID_FNN_Prediction.csv',
#  'Fake-News-Bert-Detect_Prediction.csv',
#  'roberta-fake-news_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&PolitiFact_Prediction.csv',
#  'finetune_bert_FNN_Prediction.csv',
#  'finetune_bert_CoAID_PolitiFact_Prediction.csv',
#  'Text_CNN_CoAID_predict.csv',
#  'Text_CNN_FNN_predict.csv',
#  'XLNet_on_Politi_Prediction.csv',
#  'finetune_bert_GossipCop_Prediction.csv',
#  'Text_CNN_CoAID_Politi_predict.csv',
#  'XLNet_on_FNN_Prediction.csv',
#  'roberta-fake-news_CoAID_FNN_Prediction.csv',
#  'Fake-News-Bert-Detect_PolitiFact_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv',
#  'roberta-fake-news_CoAID_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID_Prediction.csv',
#  'Text_CNN_CoAID_FNN_predict.csv']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


performance_dict = {
                    'model_name': [],
                    'accuracy': [],
                    'f1': [],
                    'precision': [],
                    'recall': []
                  }
path = path_to_prediction_folder

for attampt in prediction_csv_files:
  predictions = pd.read_csv(path+attampt)['prediction']
  performance_dict['model_name'].append(attampt)

  df_prediction=pd.read_csv(path+attampt)
  df_prediction = pd.concat([df_crowdsourcing, df_prediction], axis=1)
  df_prediction = df_prediction.dropna(how='any')

  performance_dict['accuracy'].append(accuracy_score(df_prediction['voterLabel'], df_prediction['prediction']))
  performance_dict['f1'].append( f1_score(df_prediction['voterLabel'], df_prediction['prediction']))
  performance_dict['precision'].append(precision_score(df_prediction['voterLabel'], df_prediction['prediction']))
  performance_dict['recall'].append(recall_score(df_prediction['voterLabel'], df_prediction['prediction']))
# Out:
# /Users/yunong/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pd.DataFrame(performance_dict).sort_values(by='accuracy', ascending=False)
# Out:
#                                            model_name  accuracy        f1  \
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv  0.695815  0.705587
# 19                      XLNet_on_CoAID_Prediction.csv  0.682107  0.692533
# 36             roberta-fake-news_CoAID_Prediction.csv  0.681241  0.680272
# 4                  finetune_bert_CoAID_Prediction.csv  0.660895  0.654005
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv  0.659740  0.648689
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv  0.652670  0.639832
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...  0.652381  0.636377
# 27                         Text_CNN_CoAID_predict.csv  0.642713  0.638223
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv  0.641126  0.618266
# 9                XLNet_on_CoAID_Gossip_Prediction.csv  0.638672  0.625822
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...  0.634921  0.617015
# 23                   roberta-fake-news_Prediction.csv  0.627417  0.745114
# 38                     Text_CNN_CoAID_FNN_predict.csv  0.611255  0.648761
# 16                          XLNet-base_Prediction.csv  0.607648  0.755903
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv  0.607648  0.755947
# 32                        XLNet_on_FNN_Prediction.csv  0.602597  0.696896
# 17                  Text_CNN_CoAID_Gossip_predict.csv  0.602453  0.627552
# 11        roberta-fake-news_PolitiFact_Prediction.csv  0.601443  0.644164
# 20         roberta-fake-news_GossipCop_Prediction.csv  0.600433  0.748112
# 18               XLNet_on_CoAID_Politi_Prediction.csv  0.600000  0.550292
# 5                   XLNet_on_CoAID_FNN_Prediction.csv  0.599567  0.553356
# 21             finetune_bert_CoAID_FNN_Prediction.csv  0.598990  0.551702
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv  0.596248  0.584990
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv  0.589177  0.540732
# 31                  Text_CNN_CoAID_Politi_predict.csv  0.587879  0.546954
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv  0.581385  0.519622
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv  0.579942  0.509023
# 10               roberta-fake-news_FNN_Prediction.csv  0.579509  0.665211
# 29                     XLNet_on_Politi_Prediction.csv  0.577201  0.595974
# 22               Fake-News-Bert-Detect_Prediction.csv  0.569408  0.489915
# 12                        Text_CNN_Gossip_predict.csv  0.564502  0.702484
# 7             finetune_bert_PolitiFact_Prediction.csv  0.531746  0.432593
# 28                           Text_CNN_FNN_predict.csv  0.506926  0.607196
# 25                   finetune_bert_FNN_Prediction.csv  0.506782  0.565582
# 1                      XLNet_on_Gossip_Prediction.csv  0.475902  0.561035
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv  0.468975  0.612876
# 6                         Text_CNN_Politi_predict.csv  0.468687  0.458848
# 30             finetune_bert_GossipCop_Prediction.csv  0.465801  0.559181
# 0                            bert-base_Prediction.csv  0.392352  0.000000
#
#     precision    recall
# 37   0.856562  0.599858
# 19   0.839878  0.589171
# 36   0.871016  0.558062
# 4    0.860519  0.527428
# 3    0.870452  0.516979
# 35   0.864887  0.507718
# 24   0.873239  0.500594
# 27   0.829472  0.518642
# 13   0.874132  0.478271
# 9    0.844015  0.497269
# 15   0.850939  0.483971
# 23   0.637608  0.896224
# 38   0.719283  0.590834
# 16   0.607679  0.999763
# 8    0.607648  1.000000
# 32   0.649436  0.751840
# 17   0.728500  0.551175
# 11   0.704027  0.593683
# 20   0.606311  0.976490
# 18   0.868408  0.402755
# 5    0.858641  0.408217
# 21   0.860161  0.406079
# 34   0.779139  0.468297
# 33   0.843058  0.398005
# 31   0.823698  0.409404
# 2    0.858315  0.372596
# 26   0.878347  0.358347
# 10   0.644336  0.687485
# 29   0.710622  0.513180
# 22   0.874314  0.340299
# 12   0.600539  0.846117
# 7    0.820292  0.293754
# 28   0.588458  0.627167
# 25   0.608422  0.528378
# 1    0.571253  0.551175
# 14   0.550142  0.691760
# 6    0.602005  0.370696
# 30   0.560783  0.557587
# 0    0.000000  0.000000

# %% [markdown]
# ## which model performed best when **blended** with the crowdsourced label?

# %%
from numpy.lib.function_base import average
alphas = [0.1,0.3,0.5,0.7,0.9]
for alpha in alphas:

  performance_dict = {
                    'model_name': [],
                    'blended_acc': [],
                    'model_acc':[],
                    'improvement': []
                  }
  for attampt in prediction_csv_files:
    df_prediction=pd.read_csv(path+attampt)
    df_prediction = pd.concat([df_crowdsourcing, df_prediction], axis=1)
    df_prediction = df_prediction.dropna(how='any')
    predictions = df_prediction['prediction']
    performance_dict['model_name'].append(attampt)
    attampt_file = df_prediction
    blended_acc = accuracy_score(df_crowdsourcing['label'], round(df_crowdsourcing['voterSoftLabel']*alpha +attampt_file['softLabel']*(1-alpha)))
    performance_dict['blended_acc'].append(blended_acc)
    performance_dict['model_acc'].append(attampt_file['accuracy'][0])
    performance_dict['improvement'].append(blended_acc - attampt_file['accuracy'][0])
  print('- crowdsourcing soft label * ', alpha, ' + model predict soft label * ', 1 - alpha)
  print('- average improvement: ', average(performance_dict['improvement']))
  print('- max_improvement: ', max(performance_dict['improvement']))
  max_index = performance_dict['improvement'].index(max(performance_dict['improvement']))
  print('\t at model: ', performance_dict['model_name'][max_index], ',  the previous acc is: ', performance_dict['model_acc'][max_index], ' curr: ', performance_dict['blended_acc'][max_index])
  print('- best performance: ', max(performance_dict['blended_acc']) )
  best_performance_index = performance_dict['blended_acc'].index(max(performance_dict['blended_acc']))
  print('\t at model: ', performance_dict['model_name'][best_performance_index], ',  the previous acc is: ', performance_dict['model_acc'][best_performance_index])
  print('##############################')
# Out:
# - crowdsourcing soft label *  0.1  + model predict soft label *  0.9
# - average improvement:  0.06921485134251092
# - max_improvement:  0.5645261121856868
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.990909090909091
# - best performance:  0.9911976911976912
# 	 at model:  Text_CNN_CoAID_predict.csv ,  the previous acc is:  0.8739007092198582
# ##############################
# - crowdsourcing soft label *  0.3  + model predict soft label *  0.7
# - average improvement:  0.08184666397432357
# - max_improvement:  0.5548580025175771
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.9812409812409812
# - best performance:  0.9836940836940837
# 	 at model:  Text_CNN_CoAID_predict.csv ,  the previous acc is:  0.8739007092198582
# ##############################
# - crowdsourcing soft label *  0.5  + model predict soft label *  0.5
# - average improvement:  0.08418136630902587
# - max_improvement:  0.46265021030978487
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.8890331890331891
# - best performance:  0.8914862914862914
# 	 at model:  Text_CNN_CoAID_Politi_predict.csv ,  the previous acc is:  0.7984397163120568
# ##############################
# - crowdsourcing soft label *  0.7  + model predict soft label *  0.30000000000000004
# - average improvement:  0.0626880448157044
# - max_improvement:  0.37809032574990026
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.8044733044733045
# - best performance:  0.8044733044733045
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042
# ##############################
# - crowdsourcing soft label *  0.9  + model predict soft label *  0.09999999999999998
# - average improvement:  0.02881081093847051
# - max_improvement:  0.4147530011359799
# 	 at model:  Fake-News-Bert-Detect_GossipCop_Prediction.csv ,  the previous acc is:  0.3019858156028369  curr:  0.7167388167388168
# - best performance:  0.7284271284271284
# 	 at model:  Text_CNN_Politi_predict.csv ,  the previous acc is:  0.4992907801418439
# ##############################

# %%
# best improvement after blending
pd.DataFrame(performance_dict).sort_values(by='improvement', ascending=False)
# Out:
#                                            model_name  blended_acc  model_acc  \
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv     0.716739   0.301986
# 30             finetune_bert_GossipCop_Prediction.csv     0.718615   0.361702
# 1                      XLNet_on_Gossip_Prediction.csv     0.719481   0.416454
# 12                        Text_CNN_Gossip_predict.csv     0.728427   0.426383
# 28                           Text_CNN_FNN_predict.csv     0.728427   0.444681
# 20         roberta-fake-news_GossipCop_Prediction.csv     0.717027   0.436170
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv     0.717460   0.450496
# 16                          XLNet-base_Prediction.csv     0.717460   0.450496
# 6                         Text_CNN_Politi_predict.csv     0.728427   0.499291
# 25                   finetune_bert_FNN_Prediction.csv     0.721068   0.512908
# 10               roberta-fake-news_FNN_Prediction.csv     0.721501   0.530071
# 23                   roberta-fake-news_Prediction.csv     0.719769   0.541418
# 0                            bert-base_Prediction.csv     0.724675   0.549504
# 32                        XLNet_on_FNN_Prediction.csv     0.720779   0.568227
# 11        roberta-fake-news_PolitiFact_Prediction.csv     0.723088   0.691631
# 29                     XLNet_on_Politi_Prediction.csv     0.724242   0.701560
# 7             finetune_bert_PolitiFact_Prediction.csv     0.725541   0.710071
# 38                     Text_CNN_CoAID_FNN_predict.csv     0.728427   0.721277
# 17                  Text_CNN_CoAID_Gossip_predict.csv     0.728427   0.741135
# 22               Fake-News-Bert-Detect_Prediction.csv     0.725685   0.752340
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv     0.725685   0.757730
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv     0.725830   0.792057
# 31                  Text_CNN_CoAID_Politi_predict.csv     0.728427   0.798440
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv     0.726263   0.804823
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv     0.726407   0.806667
# 21             finetune_bert_CoAID_FNN_Prediction.csv     0.725685   0.818298
# 5                   XLNet_on_CoAID_FNN_Prediction.csv     0.726407   0.823830
# 18               XLNet_on_CoAID_Politi_Prediction.csv     0.726551   0.824823
# 9                XLNet_on_CoAID_Gossip_Prediction.csv     0.726118   0.865390
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...     0.726696   0.867943
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv     0.726551   0.868652
# 27                         Text_CNN_CoAID_predict.csv     0.728427   0.873901
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...     0.726696   0.886099
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv     0.726551   0.887518
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv     0.726407   0.899291
# 4                  finetune_bert_CoAID_Prediction.csv     0.726840   0.914043
# 36             roberta-fake-news_CoAID_Prediction.csv     0.726984   0.932908
# 19                      XLNet_on_CoAID_Prediction.csv     0.727273   0.943404
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv     0.727706   0.965532
#
#     improvement
# 14     0.414753
# 30     0.356913
# 1      0.303027
# 12     0.302044
# 28     0.283746
# 20     0.280857
# 8      0.266964
# 16     0.266964
# 6      0.229136
# 25     0.208160
# 10     0.191430
# 23     0.178351
# 0      0.175172
# 32     0.152552
# 11     0.031457
# 29     0.022682
# 7      0.015470
# 38     0.007151
# 17    -0.012708
# 22    -0.026655
# 34    -0.032045
# 26    -0.066227
# 31    -0.070013
# 2     -0.078560
# 33    -0.080260
# 21    -0.092612
# 5     -0.097423
# 18    -0.098271
# 9     -0.139272
# 15    -0.141248
# 13    -0.142101
# 27    -0.145474
# 24    -0.159404
# 35    -0.160967
# 3     -0.172884
# 4     -0.187203
# 36    -0.205924
# 19    -0.216132
# 37    -0.237826

# %%
# best accuracy after blending
pd.DataFrame(performance_dict).sort_values(by='blended_acc', ascending=False)
# Out:
#                                            model_name  blended_acc  model_acc  \
# 38                     Text_CNN_CoAID_FNN_predict.csv     0.728427   0.721277
# 12                        Text_CNN_Gossip_predict.csv     0.728427   0.426383
# 31                  Text_CNN_CoAID_Politi_predict.csv     0.728427   0.798440
# 28                           Text_CNN_FNN_predict.csv     0.728427   0.444681
# 27                         Text_CNN_CoAID_predict.csv     0.728427   0.873901
# 6                         Text_CNN_Politi_predict.csv     0.728427   0.499291
# 17                  Text_CNN_CoAID_Gossip_predict.csv     0.728427   0.741135
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv     0.727706   0.965532
# 19                      XLNet_on_CoAID_Prediction.csv     0.727273   0.943404
# 36             roberta-fake-news_CoAID_Prediction.csv     0.726984   0.932908
# 4                  finetune_bert_CoAID_Prediction.csv     0.726840   0.914043
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...     0.726696   0.886099
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...     0.726696   0.867943
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv     0.726551   0.868652
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv     0.726551   0.887518
# 18               XLNet_on_CoAID_Politi_Prediction.csv     0.726551   0.824823
# 5                   XLNet_on_CoAID_FNN_Prediction.csv     0.726407   0.823830
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv     0.726407   0.806667
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv     0.726407   0.899291
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv     0.726263   0.804823
# 9                XLNet_on_CoAID_Gossip_Prediction.csv     0.726118   0.865390
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv     0.725830   0.792057
# 21             finetune_bert_CoAID_FNN_Prediction.csv     0.725685   0.818298
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv     0.725685   0.757730
# 22               Fake-News-Bert-Detect_Prediction.csv     0.725685   0.752340
# 7             finetune_bert_PolitiFact_Prediction.csv     0.725541   0.710071
# 0                            bert-base_Prediction.csv     0.724675   0.549504
# 29                     XLNet_on_Politi_Prediction.csv     0.724242   0.701560
# 11        roberta-fake-news_PolitiFact_Prediction.csv     0.723088   0.691631
# 10               roberta-fake-news_FNN_Prediction.csv     0.721501   0.530071
# 25                   finetune_bert_FNN_Prediction.csv     0.721068   0.512908
# 32                        XLNet_on_FNN_Prediction.csv     0.720779   0.568227
# 23                   roberta-fake-news_Prediction.csv     0.719769   0.541418
# 1                      XLNet_on_Gossip_Prediction.csv     0.719481   0.416454
# 30             finetune_bert_GossipCop_Prediction.csv     0.718615   0.361702
# 16                          XLNet-base_Prediction.csv     0.717460   0.450496
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv     0.717460   0.450496
# 20         roberta-fake-news_GossipCop_Prediction.csv     0.717027   0.436170
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv     0.716739   0.301986
#
#     improvement
# 38     0.007151
# 12     0.302044
# 31    -0.070013
# 28     0.283746
# 27    -0.145474
# 6      0.229136
# 17    -0.012708
# 37    -0.237826
# 19    -0.216132
# 36    -0.205924
# 4     -0.187203
# 24    -0.159404
# 15    -0.141248
# 13    -0.142101
# 35    -0.160967
# 18    -0.098271
# 5     -0.097423
# 33    -0.080260
# 3     -0.172884
# 2     -0.078560
# 9     -0.139272
# 26    -0.066227
# 21    -0.092612
# 34    -0.032045
# 22    -0.026655
# 7      0.015470
# 0      0.175172
# 29     0.022682
# 11     0.031457
# 10     0.191430
# 25     0.208160
# 32     0.152552
# 23     0.178351
# 1      0.303027
# 30     0.356913
# 16     0.266964
# 8      0.266964
# 20     0.280857
# 14     0.414753

# %% [markdown]
# ## which model had the highest performance when only taking the agreeing label between the model and the crowdsourced output, and computing accuracy on this subsection?

# %%
def agreed_accuracy(true_label_ls, voter_label_ls, pred_label_ls):
  assert len(true_label_ls) == len(voter_label_ls)
  assert len(voter_label_ls) == len(pred_label_ls)

  total = 0
  corr = 0
  for i in range(len(true_label_ls)):
    if voter_label_ls[i] == pred_label_ls[i]:
      total +=1
      if true_label_ls[i] == pred_label_ls[i]:
        corr +=1
  return corr/total, total/len(true_label_ls)

# %%
agreed_accuracy(df_crowdsourcing['label'], df_crowdsourcing['voterLabel'], attampt_file['prediction'])
# Out:
# (0.8582658959537572, 0.6134751773049646)

# %%
performance_dict = {
                    'model_name': [],
                    'accuracy': [],
                    'label_agreed':[]
                  }
                  
for attampt in prediction_csv_files:
  df_prediction=pd.read_csv(path+attampt)
  df_prediction = pd.concat([df_crowdsourcing, df_prediction], axis=1)
  df_prediction = df_prediction.dropna(how='any')
  attampt_file = df_prediction
  acc, label_agreed = agreed_accuracy(df_crowdsourcing['label'], df_crowdsourcing['voterLabel'], attampt_file['prediction'])
  predictions = pd.read_csv(path+attampt)['prediction']
  performance_dict['model_name'].append(attampt)
  performance_dict['accuracy'].append(acc)
  performance_dict['label_agreed'].append(label_agreed)

# %%
pd.DataFrame(performance_dict).sort_values(by='accuracy', ascending=False)
# Out:
#                                            model_name  accuracy  label_agreed
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv  0.985898      0.695815
# 19                      XLNet_on_CoAID_Prediction.csv  0.979691      0.682107
# 4                  finetune_bert_CoAID_Prediction.csv  0.973144      0.660895
# 36             roberta-fake-news_CoAID_Prediction.csv  0.972675      0.681241
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv  0.962598      0.659740
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...  0.959080      0.652381
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv  0.958877      0.652670
# 27                         Text_CNN_CoAID_predict.csv  0.956219      0.642713
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...  0.956136      0.634921
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv  0.952510      0.641126
# 9                XLNet_on_CoAID_Gossip_Prediction.csv  0.951875      0.638672
# 18               XLNet_on_CoAID_Politi_Prediction.csv  0.949014      0.600000
# 5                   XLNet_on_CoAID_FNN_Prediction.csv  0.948014      0.599567
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv  0.944899      0.581385
# 21             finetune_bert_CoAID_FNN_Prediction.csv  0.943146      0.598990
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv  0.939750      0.589177
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv  0.936800      0.579942
# 31                  Text_CNN_CoAID_Politi_predict.csv  0.936181      0.587879
# 22               Fake-News-Bert-Detect_Prediction.csv  0.910796      0.569408
# 7             finetune_bert_PolitiFact_Prediction.csv  0.899593      0.531746
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv  0.896418      0.596248
# 17                  Text_CNN_CoAID_Gossip_predict.csv  0.877365      0.602453
# 29                     XLNet_on_Politi_Prediction.csv  0.859000      0.577201
# 38                     Text_CNN_CoAID_FNN_predict.csv  0.857177      0.611255
# 0                            bert-base_Prediction.csv  0.841486      0.392352
# 11        roberta-fake-news_PolitiFact_Prediction.csv  0.837332      0.601443
# 32                        XLNet_on_FNN_Prediction.csv  0.735632      0.602597
# 6                         Text_CNN_Politi_predict.csv  0.733067      0.468687
# 25                   finetune_bert_FNN_Prediction.csv  0.726367      0.506782
# 10               roberta-fake-news_FNN_Prediction.csv  0.712400      0.579509
# 23                   roberta-fake-news_Prediction.csv  0.705842      0.627417
# 28                           Text_CNN_FNN_predict.csv  0.661258      0.506926
# 1                      XLNet_on_Gossip_Prediction.csv  0.641601      0.475902
# 16                          XLNet-base_Prediction.csv  0.637378      0.607648
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv  0.637378      0.607648
# 12                        Text_CNN_Gossip_predict.csv  0.628323      0.564502
# 20         roberta-fake-news_GossipCop_Prediction.csv  0.627253      0.600433
# 30             finetune_bert_GossipCop_Prediction.csv  0.587670      0.465801
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv  0.522769      0.468975
