# %% [markdown]
# # In this notebook, we analyze crowdsourced data by answering the following 3 questions:
# - which model best **predicted** the crowdsourced label?
# - which model performed best when **blended** with the crowdsourced label?
# - which model had the highest performance when only taking the agreeing label between the model and the crowdsourced output, and computing accuracy on this **subsection**?

# %% [markdown]
# ## Load crowdsourced .csv file

# %%
import pandas as pd
path_to_crowdsourced_data_csv_file = 'CorwdSourced_Data.csv'
crowdsourcing = pd.read_csv(path_to_crowdsourced_data_csv_file)
crowdsourcing.dropna(how='all').sample(2)
# Out:
#      initialLabel  binaryInitialLabel  \
# 3097        FALSE                   0
# 5359         TRUE                   1
#
#                                                   title  \
# 3097   Photos of grand celebration of Ram Navami (4/...
# 5359  WHO advance team ends visit to China to probe ...
#
#                                                     url  numTrueVotes  \
# 3097  https://www.poynter.org/?ifcn_misinformation=p...             3
# 5359  https://apnews.com/d075f9381ae9e84a8e8ecdf5040...             3
#
#       numFalseVotes  totalVotes  maxVotes  interraterPercentAgreement  \
# 3097              0           3         3                        1.00
# 5359              1           4         3                        0.75
#
#       agreementWithLabel  votersLabel  voterLabelWasAccurate  \
# 3097                0.00            1                      0
# 5359                0.75            1                      1
#
#       averageInterraterPercentAgreement  averageAgreementWithLabel  \
# 3097                                NaN                        NaN
# 5359                                NaN                        NaN
#
#       percentOfAgreeingDecisions
# 3097                         NaN
# 5359                         NaN

# %%
crowdsourcing['softLabel']=crowdsourcing['numTrueVotes']/crowdsourcing['totalVotes']
df_crowdsourcing = pd.DataFrame({'title' : crowdsourcing['title'], 'label':crowdsourcing['binaryInitialLabel'], 'voterSoftLabel':crowdsourcing['softLabel'],'voterLabel': crowdsourcing['votersLabel']})
df_crowdsourcing=df_crowdsourcing.dropna()
df_crowdsourcing = df_crowdsourcing.reset_index(drop=True)
df_crowdsourcing.sample(2)
# Out:
#                                                   title  label  \
# 5879  Bombardier reports earnings miss, hit by rail ...      1
# 5644  Bulgaria says its official who tested positive...      1
#
#       voterSoftLabel  voterLabel
# 5879             1.0           1
# 5644             1.0           1

# %% [markdown]
# ## Question 1 which model best **predicted** the crowdsourced label?

# %%
import os
path_to_prediction_folder = '../Model_Predictions/'
prediction_csv_files = os.listdir(path_to_prediction_folder)
prediction_csv_files[2]
# Out:
# 'finetune_bert_CoAID_GossipCop_Prediction.csv'

# %%
attampt = prediction_csv_files[2]
attampt_file = pd.read_csv(path_to_prediction_folder+attampt)
attampt_file.sample(2)
# Out:
#       Unnamed: 0  softLabel  label  prediction  accuracy       f1  precision  \
# 6140        6140   0.998074      1           1  0.804823  0.72892   0.973684
# 1632        1632   0.000450      0           0  0.804823  0.72892   0.973684
#
#         recall
# 6140  0.582494
# 1632  0.582494

# %% [markdown]
# List all model prediction results

# %%
prediction_csv_files
# Out:
# ['bert-base_Prediction.csv',
#  'XLNet_on_Gossip_Prediction.csv',
#  'finetune_bert_CoAID_GossipCop_Prediction.csv',
#  'roberta-fake-news_CoAID_PolitiFact_Prediction.csv',
#  'finetune_bert_CoAID_Prediction.csv',
#  'XLNet_on_CoAID_FNN_Prediction.csv',
#  'Text_CNN_Politi_predict.csv',
#  'finetune_bert_PolitiFact_Prediction.csv',
#  'Fake-News-Bert-Detect_FNN_Prediction.csv',
#  'XLNet_on_CoAID_Gossip_Prediction.csv',
#  'roberta-fake-news_FNN_Prediction.csv',
#  'roberta-fake-news_PolitiFact_Prediction.csv',
#  'Text_CNN_Gossip_predict.csv',
#  'roberta-fake-news_CoAID_GossipCop_Prediction.csv',
#  'Fake-News-Bert-Detect_GossipCop_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&GossipCop_Prediction.csv',
#  'XLNet-base_Prediction.csv',
#  'Text_CNN_CoAID_Gossip_predict.csv',
#  'XLNet_on_CoAID_Politi_Prediction.csv',
#  'XLNet_on_CoAID_Prediction.csv',
#  'roberta-fake-news_GossipCop_Prediction.csv',
#  'finetune_bert_CoAID_FNN_Prediction.csv',
#  'Fake-News-Bert-Detect_Prediction.csv',
#  'roberta-fake-news_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&PolitiFact_Prediction.csv',
#  'finetune_bert_FNN_Prediction.csv',
#  'finetune_bert_CoAID_PolitiFact_Prediction.csv',
#  'Text_CNN_CoAID_predict.csv',
#  'Text_CNN_FNN_predict.csv',
#  'XLNet_on_Politi_Prediction.csv',
#  'finetune_bert_GossipCop_Prediction.csv',
#  'Text_CNN_CoAID_Politi_predict.csv',
#  'XLNet_on_FNN_Prediction.csv',
#  'roberta-fake-news_CoAID_FNN_Prediction.csv',
#  'Fake-News-Bert-Detect_PolitiFact_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv',
#  'roberta-fake-news_CoAID_Prediction.csv',
#  'Fake-News-Bert-Detect_CoAID_Prediction.csv',
#  'Text_CNN_CoAID_FNN_predict.csv']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


performance_dict = {
                    'model_name': [],
                    'accuracy': [],
                    'f1': [],
                    'precision': [],
                    'recall': []
                  }
path = path_to_prediction_folder

for attampt in prediction_csv_files:
  predictions = pd.read_csv(path+attampt)['prediction']
  performance_dict['model_name'].append(attampt)
  performance_dict['accuracy'].append(accuracy_score(df_crowdsourcing['voterLabel'], pd.read_csv(path+attampt)['prediction']))
  performance_dict['f1'].append( f1_score(df_crowdsourcing['voterLabel'], pd.read_csv(path+attampt)['prediction']))
  performance_dict['precision'].append(precision_score(df_crowdsourcing['voterLabel'], pd.read_csv(path+attampt)['prediction']))
  performance_dict['recall'].append(recall_score(df_crowdsourcing['voterLabel'], pd.read_csv(path+attampt)['prediction']))
# Out:
# /Users/yunong/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pd.DataFrame(performance_dict).sort_values(by='accuracy', ascending=False)
# Out:
#                                            model_name  accuracy        f1  \
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv  0.701418  0.713488
# 19                      XLNet_on_CoAID_Prediction.csv  0.686950  0.699605
# 36             roberta-fake-news_CoAID_Prediction.csv  0.686099  0.687826
# 4                  finetune_bert_CoAID_Prediction.csv  0.665532  0.661596
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv  0.664681  0.656794
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv  0.657447  0.647702
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...  0.655461  0.642110
# 27                         Text_CNN_CoAID_predict.csv  0.646099  0.644131
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv  0.645957  0.626683
# 9                XLNet_on_CoAID_Gossip_Prediction.csv  0.642695  0.632852
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...  0.639291  0.624871
# 23                   roberta-fake-news_Prediction.csv  0.628511  0.746295
# 38                     Text_CNN_CoAID_FNN_predict.csv  0.613475  0.652379
# 16                          XLNet-base_Prediction.csv  0.609078  0.757009
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv  0.609078  0.757052
# 32                        XLNet_on_FNN_Prediction.csv  0.605674  0.699914
# 17                  Text_CNN_CoAID_Gossip_predict.csv  0.605532  0.632289
# 11        roberta-fake-news_PolitiFact_Prediction.csv  0.605106  0.648751
# 21             finetune_bert_CoAID_FNN_Prediction.csv  0.602695  0.559245
# 5                   XLNet_on_CoAID_FNN_Prediction.csv  0.602553  0.559711
# 18               XLNet_on_CoAID_Politi_Prediction.csv  0.602411  0.555855
# 20         roberta-fake-news_GossipCop_Prediction.csv  0.602128  0.749397
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv  0.599716  0.590540
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv  0.593617  0.549599
# 31                  Text_CNN_CoAID_Politi_predict.csv  0.589645  0.551403
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv  0.585248  0.527930
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv  0.581844  0.514173
# 10               roberta-fake-news_FNN_Prediction.csv  0.581702  0.667793
# 29                     XLNet_on_Politi_Prediction.csv  0.580993  0.601457
# 22               Fake-News-Bert-Detect_Prediction.csv  0.571064  0.494483
# 12                        Text_CNN_Gossip_predict.csv  0.565957  0.703661
# 7             finetune_bert_PolitiFact_Prediction.csv  0.533901  0.438674
# 25                   finetune_bert_FNN_Prediction.csv  0.509787  0.569185
# 28                           Text_CNN_FNN_predict.csv  0.507376  0.607881
# 1                      XLNet_on_Gossip_Prediction.csv  0.475461  0.560494
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv  0.467376  0.611565
# 6                         Text_CNN_Politi_predict.csv  0.466950  0.457564
# 30             finetune_bert_GossipCop_Prediction.csv  0.465248  0.558548
# 0                            bert-base_Prediction.csv  0.390922  0.000000
#
#     precision    recall
# 37   0.858500  0.610387
# 19   0.841795  0.598510
# 36   0.872272  0.567769
# 4    0.862004  0.536796
# 3    0.872012  0.526782
# 35   0.866849  0.517000
# 24   0.874047  0.507452
# 27   0.831064  0.525850
# 13   0.875836  0.487890
# 9    0.845734  0.505589
# 15   0.852314  0.493246
# 23   0.638912  0.897066
# 38   0.721298  0.595482
# 16   0.609109  0.999767
# 8    0.609078  1.000000
# 32   0.652314  0.755007
# 17   0.731416  0.556823
# 11   0.707874  0.598742
# 21   0.862203  0.413833
# 5    0.860386  0.414765
# 18   0.869608  0.408477
# 20   0.607914  0.976712
# 34   0.783295  0.473917
# 33   0.845670  0.407080
# 31   0.825058  0.414066
# 2    0.860526  0.380764
# 26   0.879369  0.363298
# 10   0.646738  0.690265
# 29   0.714881  0.519096
# 22   0.876185  0.344434
# 12   0.602288  0.846064
# 7    0.823077  0.299022
# 25   0.612393  0.531672
# 28   0.589963  0.626921
# 1    0.572330  0.549138
# 14   0.550158  0.688402
# 6    0.601746  0.369120
# 30   0.561705  0.555426
# 0    0.000000  0.000000

# %% [markdown]
# ## which model performed best when **blended** with the crowdsourced label?

# %%
from numpy.lib.function_base import average
alphas = [0.1,0.3,0.5,0.7,0.9]
for alpha in alphas:

  performance_dict = {
                    'model_name': [],
                    'blended_acc': [],
                    'model_acc':[],
                    'improvement': []
                  }
  for attampt in prediction_csv_files:
    predictions = pd.read_csv(path+attampt)['prediction']
    performance_dict['model_name'].append(attampt)
    attampt_file = pd.read_csv(path+attampt)
    blended_acc = accuracy_score(df_crowdsourcing['label'], round(df_crowdsourcing['voterSoftLabel']*alpha +attampt_file['softLabel']*(1-alpha)))
    performance_dict['blended_acc'].append(blended_acc)
    performance_dict['model_acc'].append(attampt_file['accuracy'][0])
    performance_dict['improvement'].append(blended_acc - attampt_file['accuracy'][0])
  print('- crowdsourcing soft label * ', alpha, ' + model predict soft label * ', 1 - alpha)
  print('- average improvement: ', average(performance_dict['improvement']))
  print('- max_improvement: ', max(performance_dict['improvement']))
  max_index = performance_dict['improvement'].index(max(performance_dict['improvement']))
  print('\t at model: ', performance_dict['model_name'][max_index], ',  the previous acc is: ', performance_dict['model_acc'][max_index], ' curr: ', performance_dict['blended_acc'][max_index])
  print('- best performance: ', max(performance_dict['blended_acc']) )
  best_performance_index = performance_dict['blended_acc'].index(max(performance_dict['blended_acc']))
  print('\t at model: ', performance_dict['model_name'][best_performance_index], ',  the previous acc is: ', performance_dict['model_acc'][best_performance_index])
  print('##############################')
# Out:
# - crowdsourcing soft label *  0.1  + model predict soft label *  0.9
# - average improvement:  0.07313329696308421
# - max_improvement:  0.5714893617021277
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.997872340425532
# - best performance:  0.9981560283687944
# 	 at model:  Text_CNN_CoAID_predict.csv ,  the previous acc is:  0.8739007092198582
# ##############################
# - crowdsourcing soft label *  0.3  + model predict soft label *  0.7
# - average improvement:  0.08593198763411529
# - max_improvement:  0.5621276595744682
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.9885106382978723
# - best performance:  0.9907801418439717
# 	 at model:  Text_CNN_CoAID_predict.csv ,  the previous acc is:  0.8739007092198582
# ##############################
# - crowdsourcing soft label *  0.5  + model predict soft label *  0.5
# - average improvement:  0.08745590107292237
# - max_improvement:  0.4679432624113476
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.8943262411347518
# - best performance:  0.8963120567375886
# 	 at model:  Text_CNN_CoAID_Politi_predict.csv ,  the previous acc is:  0.7984397163120568
# ##############################
# - crowdsourcing soft label *  0.7  + model predict soft label *  0.30000000000000004
# - average improvement:  0.06621567557737773
# - max_improvement:  0.3845390070921986
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042  curr:  0.8109219858156028
# - best performance:  0.8109219858156028
# 	 at model:  Text_CNN_Gossip_predict.csv ,  the previous acc is:  0.4263829787234042
# ##############################
# - crowdsourcing soft label *  0.9  + model predict soft label *  0.09999999999999998
# - average improvement:  0.03088197854155301
# - max_improvement:  0.4147517730496454
# 	 at model:  Fake-News-Bert-Detect_GossipCop_Prediction.csv ,  the previous acc is:  0.3019858156028369  curr:  0.7167375886524823
# - best performance:  0.7314893617021276
# 	 at model:  Text_CNN_Politi_predict.csv ,  the previous acc is:  0.4992907801418439
# ##############################

# %%
# best improvement after blending
pd.DataFrame(performance_dict).sort_values(by='improvement', ascending=False)
# Out:
#                                            model_name  blended_acc  model_acc  \
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv     0.716738   0.301986
# 30             finetune_bert_GossipCop_Prediction.csv     0.719007   0.361702
# 12                        Text_CNN_Gossip_predict.csv     0.731489   0.426383
# 1                      XLNet_on_Gossip_Prediction.csv     0.719858   0.416454
# 28                           Text_CNN_FNN_predict.csv     0.731489   0.444681
# 20         roberta-fake-news_GossipCop_Prediction.csv     0.717730   0.436170
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv     0.718298   0.450496
# 16                          XLNet-base_Prediction.csv     0.718298   0.450496
# 6                         Text_CNN_Politi_predict.csv     0.731489   0.499291
# 25                   finetune_bert_FNN_Prediction.csv     0.721560   0.512908
# 10               roberta-fake-news_FNN_Prediction.csv     0.722837   0.530071
# 23                   roberta-fake-news_Prediction.csv     0.720993   0.541418
# 0                            bert-base_Prediction.csv     0.725390   0.549504
# 32                        XLNet_on_FNN_Prediction.csv     0.721560   0.568227
# 11        roberta-fake-news_PolitiFact_Prediction.csv     0.725390   0.691631
# 29                     XLNet_on_Politi_Prediction.csv     0.726383   0.701560
# 7             finetune_bert_PolitiFact_Prediction.csv     0.727092   0.710071
# 38                     Text_CNN_CoAID_FNN_predict.csv     0.731489   0.721277
# 17                  Text_CNN_CoAID_Gossip_predict.csv     0.731489   0.741135
# 22               Fake-News-Bert-Detect_Prediction.csv     0.727092   0.752340
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv     0.727801   0.757730
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv     0.727943   0.792057
# 31                  Text_CNN_CoAID_Politi_predict.csv     0.731489   0.798440
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv     0.728369   0.804823
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv     0.729078   0.806667
# 21             finetune_bert_CoAID_FNN_Prediction.csv     0.728227   0.818298
# 5                   XLNet_on_CoAID_FNN_Prediction.csv     0.728794   0.823830
# 18               XLNet_on_CoAID_Politi_Prediction.csv     0.728652   0.824823
# 9                XLNet_on_CoAID_Gossip_Prediction.csv     0.728369   0.865390
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...     0.729220   0.867943
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv     0.728794   0.868652
# 27                         Text_CNN_CoAID_predict.csv     0.731489   0.873901
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...     0.729220   0.886099
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv     0.729787   0.887518
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv     0.729362   0.899291
# 4                  finetune_bert_CoAID_Prediction.csv     0.730071   0.914043
# 36             roberta-fake-news_CoAID_Prediction.csv     0.729787   0.932908
# 19                      XLNet_on_CoAID_Prediction.csv     0.730496   0.943404
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv     0.730922   0.965532
#
#     improvement
# 14     0.414752
# 30     0.357305
# 12     0.305106
# 1      0.303404
# 28     0.286809
# 20     0.281560
# 8      0.267801
# 16     0.267801
# 6      0.232199
# 25     0.208652
# 10     0.192766
# 23     0.179574
# 0      0.175887
# 32     0.153333
# 11     0.033759
# 29     0.024823
# 7      0.017021
# 38     0.010213
# 17    -0.009645
# 22    -0.025248
# 34    -0.029929
# 26    -0.064113
# 31    -0.066950
# 2     -0.076454
# 33    -0.077589
# 21    -0.090071
# 5     -0.095035
# 18    -0.096170
# 9     -0.137021
# 15    -0.138723
# 13    -0.139858
# 27    -0.142411
# 24    -0.156879
# 35    -0.157730
# 3     -0.169929
# 4     -0.183972
# 36    -0.203121
# 19    -0.212908
# 37    -0.234610

# %%
# best accuracy after blending
pd.DataFrame(performance_dict).sort_values(by='blended_acc', ascending=False)
# Out:
#                                            model_name  blended_acc  model_acc  \
# 38                     Text_CNN_CoAID_FNN_predict.csv     0.731489   0.721277
# 12                        Text_CNN_Gossip_predict.csv     0.731489   0.426383
# 31                  Text_CNN_CoAID_Politi_predict.csv     0.731489   0.798440
# 28                           Text_CNN_FNN_predict.csv     0.731489   0.444681
# 27                         Text_CNN_CoAID_predict.csv     0.731489   0.873901
# 6                         Text_CNN_Politi_predict.csv     0.731489   0.499291
# 17                  Text_CNN_CoAID_Gossip_predict.csv     0.731489   0.741135
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv     0.730922   0.965532
# 19                      XLNet_on_CoAID_Prediction.csv     0.730496   0.943404
# 4                  finetune_bert_CoAID_Prediction.csv     0.730071   0.914043
# 36             roberta-fake-news_CoAID_Prediction.csv     0.729787   0.932908
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv     0.729787   0.887518
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv     0.729362   0.899291
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...     0.729220   0.886099
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...     0.729220   0.867943
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv     0.729078   0.806667
# 5                   XLNet_on_CoAID_FNN_Prediction.csv     0.728794   0.823830
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv     0.728794   0.868652
# 18               XLNet_on_CoAID_Politi_Prediction.csv     0.728652   0.824823
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv     0.728369   0.804823
# 9                XLNet_on_CoAID_Gossip_Prediction.csv     0.728369   0.865390
# 21             finetune_bert_CoAID_FNN_Prediction.csv     0.728227   0.818298
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv     0.727943   0.792057
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv     0.727801   0.757730
# 7             finetune_bert_PolitiFact_Prediction.csv     0.727092   0.710071
# 22               Fake-News-Bert-Detect_Prediction.csv     0.727092   0.752340
# 29                     XLNet_on_Politi_Prediction.csv     0.726383   0.701560
# 11        roberta-fake-news_PolitiFact_Prediction.csv     0.725390   0.691631
# 0                            bert-base_Prediction.csv     0.725390   0.549504
# 10               roberta-fake-news_FNN_Prediction.csv     0.722837   0.530071
# 25                   finetune_bert_FNN_Prediction.csv     0.721560   0.512908
# 32                        XLNet_on_FNN_Prediction.csv     0.721560   0.568227
# 23                   roberta-fake-news_Prediction.csv     0.720993   0.541418
# 1                      XLNet_on_Gossip_Prediction.csv     0.719858   0.416454
# 30             finetune_bert_GossipCop_Prediction.csv     0.719007   0.361702
# 16                          XLNet-base_Prediction.csv     0.718298   0.450496
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv     0.718298   0.450496
# 20         roberta-fake-news_GossipCop_Prediction.csv     0.717730   0.436170
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv     0.716738   0.301986
#
#     improvement
# 38     0.010213
# 12     0.305106
# 31    -0.066950
# 28     0.286809
# 27    -0.142411
# 6      0.232199
# 17    -0.009645
# 37    -0.234610
# 19    -0.212908
# 4     -0.183972
# 36    -0.203121
# 35    -0.157730
# 3     -0.169929
# 24    -0.156879
# 15    -0.138723
# 33    -0.077589
# 5     -0.095035
# 13    -0.139858
# 18    -0.096170
# 2     -0.076454
# 9     -0.137021
# 21    -0.090071
# 26    -0.064113
# 34    -0.029929
# 7      0.017021
# 22    -0.025248
# 29     0.024823
# 11     0.033759
# 0      0.175887
# 10     0.192766
# 25     0.208652
# 32     0.153333
# 23     0.179574
# 1      0.303404
# 30     0.357305
# 16     0.267801
# 8      0.267801
# 20     0.281560
# 14     0.414752

# %% [markdown]
# ## which model had the highest performance when only taking the agreeing label between the model and the crowdsourced output, and computing accuracy on this subsection?

# %%
def agreed_accuracy(true_label_ls, voter_label_ls, pred_label_ls):
  assert len(true_label_ls) == len(voter_label_ls)
  assert len(voter_label_ls) == len(pred_label_ls)

  total = 0
  corr = 0
  for i in range(len(true_label_ls)):
    if voter_label_ls[i] == pred_label_ls[i]:
      total +=1
      if true_label_ls[i] == pred_label_ls[i]:
        corr +=1
  return corr/total, total/len(true_label_ls)

# %%
agreed_accuracy(df_crowdsourcing['label'], df_crowdsourcing['voterLabel'], attampt_file['prediction'])
# Out:
# (0.8582658959537572, 0.6134751773049646)

# %%
performance_dict = {
                    'model_name': [],
                    'accuracy': [],
                    'label_agreed':[]
                  }
                  
for attampt in prediction_csv_files:
  attampt_file = pd.read_csv(path+attampt)
  acc, label_agreed = agreed_accuracy(df_crowdsourcing['label'], df_crowdsourcing['voterLabel'], attampt_file['prediction'])
  predictions = pd.read_csv(path+attampt)['prediction']
  performance_dict['model_name'].append(attampt)
  performance_dict['accuracy'].append(acc)
  performance_dict['label_agreed'].append(label_agreed)

# %%
pd.DataFrame(performance_dict).sort_values(by='accuracy', ascending=False)
# Out:
#                                            model_name  accuracy  label_agreed
# 37         Fake-News-Bert-Detect_CoAID_Prediction.csv  0.987462      0.701418
# 19                      XLNet_on_CoAID_Prediction.csv  0.981623      0.686950
# 4                  finetune_bert_CoAID_Prediction.csv  0.975064      0.665532
# 36             roberta-fake-news_CoAID_Prediction.csv  0.974571      0.686099
# 3   roberta-fake-news_CoAID_PolitiFact_Prediction.csv  0.964575      0.664681
# 24  Fake-News-Bert-Detect_CoAID&PolitiFact_Predict...  0.961047      0.655461
# 35     Fake-News-Bert-Detect_CoAID&FNN_Prediction.csv  0.960734      0.657447
# 15  Fake-News-Bert-Detect_CoAID&GossipCop_Predicti...  0.958509      0.639291
# 27                         Text_CNN_CoAID_predict.csv  0.958068      0.646099
# 13   roberta-fake-news_CoAID_GossipCop_Prediction.csv  0.954326      0.645957
# 9                XLNet_on_CoAID_Gossip_Prediction.csv  0.954094      0.642695
# 18               XLNet_on_CoAID_Politi_Prediction.csv  0.950789      0.602411
# 5                   XLNet_on_CoAID_FNN_Prediction.csv  0.949859      0.602553
# 2        finetune_bert_CoAID_GossipCop_Prediction.csv  0.946922      0.585248
# 21             finetune_bert_CoAID_FNN_Prediction.csv  0.945164      0.602695
# 33         roberta-fake-news_CoAID_FNN_Prediction.csv  0.942174      0.593617
# 26      finetune_bert_CoAID_PolitiFact_Prediction.csv  0.938567      0.581844
# 31                  Text_CNN_CoAID_Politi_predict.csv  0.937936      0.589645
# 22               Fake-News-Bert-Detect_Prediction.csv  0.912072      0.571064
# 7             finetune_bert_PolitiFact_Prediction.csv  0.901169      0.533901
# 34    Fake-News-Bert-Detect_PolitiFact_Prediction.csv  0.896878      0.599716
# 17                  Text_CNN_CoAID_Gossip_predict.csv  0.879363      0.605532
# 29                     XLNet_on_Politi_Prediction.csv  0.861328      0.580993
# 38                     Text_CNN_CoAID_FNN_predict.csv  0.858266      0.613475
# 0                            bert-base_Prediction.csv  0.842525      0.390922
# 11        roberta-fake-news_PolitiFact_Prediction.csv  0.838725      0.605106
# 32                        XLNet_on_FNN_Prediction.csv  0.736534      0.605674
# 6                         Text_CNN_Politi_predict.csv  0.733293      0.466950
# 25                   finetune_bert_FNN_Prediction.csv  0.726767      0.509787
# 10               roberta-fake-news_FNN_Prediction.csv  0.713485      0.581702
# 23                   roberta-fake-news_Prediction.csv  0.706613      0.628511
# 28                           Text_CNN_FNN_predict.csv  0.660889      0.507376
# 1                      XLNet_on_Gossip_Prediction.csv  0.641706      0.475461
# 16                          XLNet-base_Prediction.csv  0.638565      0.609078
# 8            Fake-News-Bert-Detect_FNN_Prediction.csv  0.638565      0.609078
# 20         roberta-fake-news_GossipCop_Prediction.csv  0.628269      0.602128
# 12                        Text_CNN_Gossip_predict.csv  0.628070      0.565957
# 30             finetune_bert_GossipCop_Prediction.csv  0.585976      0.465248
# 14     Fake-News-Bert-Detect_GossipCop_Prediction.csv  0.521700      0.467376
